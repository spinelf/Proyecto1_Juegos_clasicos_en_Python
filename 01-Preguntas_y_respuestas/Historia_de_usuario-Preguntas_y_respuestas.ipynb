# %% [markdown]
# ### PREGUNTAS Y RESPUESTAS
#
# #### DESCRIPCIÓN:
# - El juego va a constar de 10 preguntas aleatorias sobre geografía.
# - Cada pregunta tendrá tres opciones de respuesta (a, b, c) y sólo una será correcta.
# - Se obtiene un punto por cada respuesta acertada.
#
# #### REGLAS DEL JUEGO:
# - A DEFINIR!!!!! El jugador tendrá dos intentos por cada pregunta.
# - El jugador empieza con 3 vidas y se le restará una cada vez que conteste incorrectamente una pregunta.
# - El juego termina si el jugador pierde todas sus vidas o si responde a 5 preguntas correctamente.
#
# #### CRITERIOS DE ACEPTACIÓN:
# - Las preguntas y respuestas deben de estar comprendidas en un diccionario.
# - Utiliza una función para seleccionar una pregunta aleatoria del diccionario.
# - Utiliza un bucle 'while' para hacer preguntas hasta que el jugador pierda todas sus vidas o responda un número específico de preguntas correctamente.
# - Presenta la pregunta al jugador y permitele que responda dentro del bucle 'while'.
# - Lleva un seguimiento del número de preguntas realizadas y el número de respuestas correctas
# - Determina las condiciones de victoria y derrota del juego y sal del bucle cuando se cumplan estas condiciones
#
# #### EXTRAS:
# -	Si acierta (“Sigue jugando”), si falla (“Vamos descontando oportunidades”).
# - Imprimir en la pantall las preguntas y las possibles respuestas, y que cada una de éstas esté en una línea distinta.
#
# ##### PREGUNTAS Y RESPUESTAS:
#
# 1. ¿Cuál es el río más largo de la Península Ibérica?
#    - a) Tajo.
#    - b) Guadiana.
#    - c) Ebro.
# 2. ¿Cuál es el país más pequeño del mundo?
#    - a) Francia.
#    - b) Portugal.
#    - c) El Vaticano.
# 3. ¿Cuántos océanos hay en la Tierra?
#    - a) Cuatro.
#    - b) Cinco.
#    - c) Tres.
# 4. ¿Qué país tiene más habitantes?
#    - a) España.
#    - b) Austria.
#    - c) China.
# 5. ¿Qué país es el más grande del mundo?
#    - a) Rusia.
#    - b) Hungría.
#    - c) Italia.
# 6. ¿Cuál es la montaña más alta del mundo?
#    - a) Everest.
#    - b) Kilimanjaro.
#    - c) Teide.
# 7. ¿Cuál es el río más largo del mundo?
#    - a) Nilo.
#    - b) Amazonas.
#    - c) Támesis.
# 8. ¿Cuál es la capital de Francia?
#    - a) Roma.
#    - b) París.
#    - c) Londres.
# 9. ¿Dónde podemos ver las auroras boreales?
#    - a) Finlandia.
#    - b) Suiza.
#    - c) Dinamarca.
# 1. ¿Cuál es la capital de España?
#    - a) Barcelona.
#    - b) Sevilla.
#    - c) Madrid.
